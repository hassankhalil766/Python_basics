# %%
age = int(input())
if (age<13):
    print("The passenger is child")
elif(age>=13 and age<=18):
    print("The passenger is teenager")
elif(age>18):
    print("The passenger is adult")
# Out:
#  19
# The passenger is adult
